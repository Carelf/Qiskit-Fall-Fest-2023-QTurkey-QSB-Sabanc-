# %% [markdown]
# <a href="https://colab.research.google.com/github/sbbzplt/QiskitFallFest_IZTECH/blob/master/Adder_and_counting_solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit
# !pip install pylatexenc

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit import IBMQ, Aer, execute

# %% [markdown]
# ### Task 1
# Add the first three bits stored in qubits 0-2 and store the sum on qubits 3-4.

# %% [markdown]
# ### Solution

# %%
for input in  ['000','001','010','011','100','101','110','111']:
    qc = QuantumCircuit(5,5)

    if input[0] == '1':
        qc.x(0)
    if input[1] == '1':
        qc.x(1)
    if input[2] == '1':
        qc.x(2)

    # add qubit 0
    qc.ccx(0,3,4)
    qc.cx(0,3)

    # add qubit 1
    qc.ccx(1,3,4)
    qc.cx(1,3)

    # add qubit 2
    qc.ccx(2,3,4)
    qc.cx(2,3)
    
    #Measure in reverse order
    for i in range(5):
        qc.measure(i,4-i)

    job = execute(qc,Aer.get_backend('qasm_simulator'),shots=1000)
    counts = job.result().get_counts(qc)   
    # print the sum
    print("Input:", input)
    print("The sum should be equal to", int(input[0])+int(input[1])+int(input[2]))
    print("According to quantum circuit:", 2*int(list(counts.keys())[0][4]) + int(list(counts.keys())[0][3])) 
    print("")
# Out:
# Input: 000
# The sum should be equal to 0
# According to quantum circuit: 0
#
# Input: 001
# The sum should be equal to 1
# According to quantum circuit: 1
#
# Input: 010
# The sum should be equal to 1
# According to quantum circuit: 1
#
# Input: 011
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 100
# The sum should be equal to 1
# According to quantum circuit: 1
#
# Input: 101
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 110
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 111
# The sum should be equal to 3
# According to quantum circuit: 3

# %% [markdown]
# ### Task 2
#
# By using the given idea, add the values of seven bits, namely $ q_0,\ldots,q_6 $, and write the results on the qubits $ q_7,q_8, q_9 $.
#
# *Note:*  You may use for-loops instead of adding each qubit one by one.

# %% [markdown]
# ### Solution

# %%
# Generate the inputs
input_list = [bin(i)[2:].zfill(7) for i in range(0,2**7)]

# %%
for input in input_list:
    qc = QuantumCircuit(10,10)

    #We can do the initialization inside a for loop
    for i in range(7):
        if input[i]=='1':
            qc.x(i)

    # add qubit 0
    qc.cx(0,7)

    # add qubit 1
    qc.ccx(1,7,8)
    qc.cx(1,7)

    # add qubit 2
    qc.ccx(2,7,8)
    qc.cx(2,7)

    # add qubit 3
    qc.mct([3,7,8],9)
    qc.ccx(3,7,8)
    qc.cx(3,7)
    
    # add qubit 4
    qc.mct([4,7,8],9)
    qc.ccx(4,7,8)
    qc.cx(4,7)
    
    # add qubit 5
    qc.mct([5,7,8],9)
    qc.ccx(5,7,8)
    qc.cx(5,7)
    
    # add qubit 6
    qc.mct([6,7,8],9)
    qc.ccx(6,7,8)
    qc.cx(6,7)
    
    #Measure in reverse order
    for i in range(10):
        qc.measure(i,9-i)

    job = execute(qc,Aer.get_backend('qasm_simulator'),shots=1000)
    counts = job.result().get_counts(qc)   
    # print the sum
    print("Input:", input)
    print("The sum should be equal to",  sum(int(i) for i in input))
    print("According to quantum circuit:",4*int(list(counts.keys())[0][9])+ 2*int(list(counts.keys())[0][8]) + int(list(counts.keys())[0][7])) 
    print("")
# Out:
# Input: 0000000
# The sum should be equal to 0
# According to quantum circuit: 0
#
# Input: 0000001
# The sum should be equal to 1
# According to quantum circuit: 1
#
# Input: 0000010
# The sum should be equal to 1
# According to quantum circuit: 1
#
# Input: 0000011
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0000100
# The sum should be equal to 1
# According to quantum circuit: 1
#
# Input: 0000101
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0000110
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0000111
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0001000
# The sum should be equal to 1
# According to quantum circuit: 1
#
# Input: 0001001
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0001010
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0001011
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0001100
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0001101
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0001110
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0001111
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0010000
# The sum should be equal to 1
# According to quantum circuit: 1
#
# Input: 0010001
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0010010
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0010011
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0010100
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0010101
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0010110
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0010111
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0011000
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0011001
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0011010
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0011011
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0011100
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0011101
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0011110
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0011111
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 0100000
# The sum should be equal to 1
# According to quantum circuit: 1
#
# Input: 0100001
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0100010
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0100011
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0100100
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0100101
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0100110
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0100111
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0101000
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0101001
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0101010
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0101011
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0101100
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0101101
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0101110
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0101111
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 0110000
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 0110001
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0110010
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0110011
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0110100
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0110101
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0110110
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0110111
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 0111000
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 0111001
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0111010
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0111011
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 0111100
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 0111101
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 0111110
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 0111111
# The sum should be equal to 6
# According to quantum circuit: 6
#
# Input: 1000000
# The sum should be equal to 1
# According to quantum circuit: 1
#
# Input: 1000001
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 1000010
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 1000011
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1000100
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 1000101
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1000110
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1000111
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1001000
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 1001001
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1001010
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1001011
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1001100
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1001101
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1001110
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1001111
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1010000
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 1010001
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1010010
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1010011
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1010100
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1010101
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1010110
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1010111
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1011000
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1011001
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1011010
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1011011
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1011100
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1011101
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1011110
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1011111
# The sum should be equal to 6
# According to quantum circuit: 6
#
# Input: 1100000
# The sum should be equal to 2
# According to quantum circuit: 2
#
# Input: 1100001
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1100010
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1100011
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1100100
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1100101
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1100110
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1100111
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1101000
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1101001
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1101010
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1101011
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1101100
# The sum should be equal to 4
# According to quantum circuit: 4
# Input: 1101101
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1101110
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1101111
# The sum should be equal to 6
# According to quantum circuit: 6
#
# Input: 1110000
# The sum should be equal to 3
# According to quantum circuit: 3
#
# Input: 1110001
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1110010
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1110011
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1110100
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1110101
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1110110
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1110111
# The sum should be equal to 6
# According to quantum circuit: 6
#
# Input: 1111000
# The sum should be equal to 4
# According to quantum circuit: 4
#
# Input: 1111001
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1111010
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1111011
# The sum should be equal to 6
# According to quantum circuit: 6
#
# Input: 1111100
# The sum should be equal to 5
# According to quantum circuit: 5
#
# Input: 1111101
# The sum should be equal to 6
# According to quantum circuit: 6
#
# Input: 1111110
# The sum should be equal to 6
# According to quantum circuit: 6
#
# Input: 1111111
# The sum should be equal to 7
# According to quantum circuit: 7
